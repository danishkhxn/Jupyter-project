# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv('Heart Disease data.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df2=df.head(10)
df2
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
print(df2['sex'].value_counts())
print(df2['cp'].value_counts())
print(df2['slope'].value_counts())
print(df2['ca'].value_counts())
print(df2['fbs'].value_counts())
print(df2['restecg'].value_counts())
print(df2['thal'].value_counts())
print(df2['target'].value_counts())
print(df2['exang'].value_counts())
# Out:
# sex
# 1    8
# 0    2
# Name: count, dtype: int64
# cp
# 0    10
# Name: count, dtype: int64
# slope
# 1    4
# 2    3
# 0    3
# Name: count, dtype: int64
# ca
# 0    4
# 2    2
# 1    2
# 3    2
# Name: count, dtype: int64
# fbs
# 0    8
# 1    2
# Name: count, dtype: int64
# restecg
# 0    5
# 1    4
# 2    1
# Name: count, dtype: int64
# thal
# 3    6
# 2    3
# 1    1
# Name: count, dtype: int64
# target
# 0    9
# 1    1
# Name: count, dtype: int64
# exang
# 0    6
# 1    4
# Name: count, dtype: int64

# %%
print(df2[['age','trestbps','chol','thalach','oldpeak']].describe())
# Out:
#              age    trestbps        chol    thalach    oldpeak
# count  10.000000   10.000000   10.000000   10.00000  10.000000
# mean   56.900000  131.200000  247.600000  138.20000   1.880000
# std     6.556591   18.084985   48.261326   20.38409   1.395071
# min    46.000000  100.000000  174.000000  106.00000   0.000000
# 25%    53.250000  120.500000  205.250000  122.75000   0.850000
# 50%    56.500000  131.500000  248.500000  142.00000   1.450000
# 75%    60.250000  143.750000  288.250000  152.50000   2.975000
# max    70.000000  160.000000  318.000000  168.00000   4.400000

# %%
for col in ['sex','trestbps','chol','thalach','oldpeak']:
    sns.countplot(x=col,data=df2)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
numeric_cols=['age','trestbps','chol','thalach','oldpeak']
for col in numeric_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(df2[col])
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
corr=df2.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x='target',data=df2)
plt.show()

# %%
for col in ['age','trestbps','chol','thalach','oldpeak']:
    sns.boxplot(x='target',y=col,data=df2)
    plt.show()

# %%
sns.pairplot(df2[['age','trestbps','chol','thalach','oldpeak','target']],hue='target')
plt.show()
