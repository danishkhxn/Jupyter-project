# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Financial Analytics data.csv')
df
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0        1   Reliance Inds.        583436.72           99810.00         NaN
# 1        2              TCS        563709.84           30904.00         NaN
# 2        3        HDFC Bank        482953.59           20581.27         NaN
# 3        4              ITC        320985.27            9772.02         NaN
# 4        5          H D F C        289497.37           16840.51         NaN
# ..     ...              ...              ...                ...         ...
# 483    496  Lak. Vilas Bank          3029.57             790.17         NaN
# 484    497            NOCIL          3026.26             249.27         NaN
# 485    498    Orient Cement          3024.32             511.53         NaN
# 486    499  Natl.Fertilizer          3017.07            2840.75         NaN
# 487    500        L T Foods              NaN                NaN         NaN
#
# [488 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# S.No.                  0
# Name                   0
# Mar Cap - Crore        9
# Sales Qtr - Crore    123
# Unnamed: 4           394
# dtype: int64

# %%
df.drop('Unnamed: 4',axis=1,inplace=True)

# %%
df2=df.head(100)

# %%
df2.dropna()
df2
# Out:
#     S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0       1  Reliance Inds.        583436.72           99810.00
# 1       2             TCS        563709.84           30904.00
# 2       3       HDFC Bank        482953.59           20581.27
# 3       4             ITC        320985.27            9772.02
# 4       5         H D F C        289497.37           16840.51
# ..    ...             ...              ...                ...
# 95     96  Bajaj Holdings         30305.94                NaN
# 96     97   P & G Hygiene         30202.12                NaN
# 97     98             MRF         30030.01                NaN
# 98     99  Shriram Trans.         29327.64                NaN
# 99    100   Colgate-Palm.              NaN                NaN
#
# [100 rows x 4 columns]

# %%
df2.columns
# Out:
# Index(['S.No.', 'Name', 'Mar Cap - Crore', 'Sales Qtr - Crore'], dtype='object')

# %%
df2.dtypes
# Out:
# S.No.                  int64
# Name                  object
# Mar Cap - Crore      float64
# Sales Qtr - Crore    float64
# dtype: object

# %%
df.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  488.000000       479.000000         365.000000
# mean   251.508197     28043.857119        4395.976849
# std    145.884078     59464.615831       11092.206185
# min      1.000000      3017.070000          47.240000
# 25%    122.750000      4843.575000         593.740000
# 50%    252.500000      9885.050000        1278.300000
# 75%    378.250000     23549.900000        2840.750000
# max    500.000000    583436.720000      110666.930000

# %%
#Distribution of Market cap
plt.figure(figsize=(12,5))
sns.histplot(data=df['Mar Cap - Crore'],kde=True)
plt.title('Market cap Distribution')
plt.xlabel('market cap (crore)')
plt.show()

# %%
#Bar chart for Sales by company
plt.figure(figsize=(12,16))
sns.barplot(x='Sales Qtr - Crore',y='Name',data=df2)
plt.title('Boxplot of Market Cap')
plt.show()

# %%
sns.boxplot(x=df2['Mar Cap - Crore'])
plt.title('Boxplot of Market Cap')
plt.show()

# %%
#Correlation between Market Cap and Sales Qtr
corr=df[['Mar Cap - Crore','Sales Qtr - Crore']].corr()
corr
# Out:
#                    Mar Cap - Crore  Sales Qtr - Crore
# Mar Cap - Crore           1.000000           0.620702
# Sales Qtr - Crore         0.620702           1.000000

# %%
#Visualizing the correlation
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title('Correaltion Matrix')
plt.show()

# %%
pip install pandas openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (2.2.2)
# Requirement already satisfied: openpyxl in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
df3=df.head(15)
df3
# Out:
#     S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore
# 0       1   Reliance Inds.        583436.72           99810.00
# 1       2              TCS        563709.84           30904.00
# 2       3        HDFC Bank        482953.59           20581.27
# 3       4              ITC        320985.27            9772.02
# 4       5          H D F C        289497.37           16840.51
# 5       6   Hind. Unilever        288265.26            8590.00
# 6       7    Maruti Suzuki        263493.81           19283.20
# 7       8          Infosys        248320.35           17794.00
# 8       9          O N G C        239981.50           22995.88
# 9      10   St Bk of India        232763.33           57014.08
# 10     11       ICICI Bank        203802.35           13665.35
# 11     12  Kotak Mah. Bank        199253.77            6390.71
# 12     13       Coal India        192677.98           21643.28
# 13     14  Larsen & Toubro        180860.74           28747.45
# 14     15          I O C L        178017.48          110666.93

# %% [markdown]
# df3.to_excel('finance.xlsx')
